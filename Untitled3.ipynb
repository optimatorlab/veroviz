# %%
import veroviz as vrv
import os

# %%
shapepoints2D = vrv.getShapepoints2D(
     odID             = 1,
     startLoc         = [42.80, -78.80],
     endLoc           = [42.90, -78.80],
     routeType        = 'fastest',
     dataProvider     = 'ors-online',
     dataProviderArgs = {'APIkey': os.environ['ORSKEY']})
shapepoints2D
# Out:
# ...
#
# ...

# %%
extras = {0: 'blah'}
i = 1
startElev = 3 if (i-1) in extras else 'None'

startElev
# Out:
# 3

# %%
shapepoints2D
# Out:
#     odID objectID modelFile modelScale modelMinPxSize  startTimeSec  \
# 0      1     None      None        100             75      0.000000
# 1      1     None      None        100             75      6.472694
# 2      1     None      None        100             75     12.100000
# 3      1     None      None        100             75     24.120738
# 4      1     None      None        100             75     44.638127
# ..   ...      ...       ...        ...            ...           ...
# 199    1     None      None        100             75   1123.400000
# 200    1     None      None        100             75   1124.939389
# 201    1     None      None        100             75   1126.929021
# 202    1     None      None        100             75   1131.766742
# 203    1     None      None        100             75   1138.906588
#
#       startLat   startLon startAltMeters   endTimeSec  ...  cesiumOpacity  \
# 0    42.801336 -78.802702              0     6.472694  ...            0.8
# ...

# %%
data = {
"type":"FeatureCollection",

"features":[
	{
	"bbox":[8.681436,49.41461,114,8.690123,49.420514,118.73],
	"type":"Feature",
	"properties":
		{
		"ascent":5.9,
		"descent":1.2,
		"segments":
			[
			{
				"distance":1322.8,
				"duration":305,
				"steps":
				[
				{
				"distance":413.4,
				"duration":99.2,
				"type":11,
				"instruction":"Head north on Wielandtstraße",
				"name":"Wielandtstraße",
				"way_points":[0,15]
				},
				
				{
				"distance":130,
				"duration":31.2,
				"type":1,
				"instruction":"Turn right onto Seitzstraße",
				"name":"Seitzstraße",
				"way_points":[15,18]
				},
				
				{
				"distance":54.3,
				"duration":13,
				"type":0,
				"instruction":"Turn left onto Quinckestraße",
				"name":"Quinckestraße",
				"way_points":[18,21]
				},
				
				{
				"distance":511.5,
				"duration":122.8,
				"type":1,
				"instruction":"Turn right onto Moltkestraße",
				"name":"Moltkestraße",
				"way_points":[21,35]
				},
				
				{
				"distance":83,
				"duration":7.5,
				"type":0,
				"instruction":"Turn left onto Handschuhsheimer Landstraße, B 3",
				"name":"Handschuhsheimer Landstraße, B 3",
				"way_points":[35,37]
				},
				
				{
				"distance":130.6,
				"duration":31.4,
				"type":0,
				"instruction":"Turn left onto Roonstraße",
				"name":"Roonstraße",
				"way_points":[37,40]
				},
				
				{
				"distance":0,
				"duration":0,
				"type":10,
				"instruction":"Arrive at Roonstraße, straight ahead",
				"name":"-",
				"way_points":[40,40]
				}
				],
				"ascent":5.8951388888889085,
				"descent":1.1701388888889142}
			],
		"extras":{
			"waycategory":
				{
				"values":[[0,40,0]],
				"summary":[
					{
					"value":0,
					"distance":1322.8,
					"amount":100
					}
				]
				},
				
			"surface":
				{
				"values":[[0,40,3]],
				"summary":[
					{
					"value":3,
					"distance":1322.8,
					"amount":100
					}
				]
			},
			"waytypes":
				{
				"values":[[0,35,3],[35,37,1],[37,40,3]],
				"summary":[
					{
					"value":3,
					"distance":1239.8,
					"amount":93.73
					},
					{
					"value":1,
					"distance":83,
					"amount":6.27
					}
				]
			},
			"steepness":
				{
				"values":[[0,40,0]],
				"summary":[
					{
					"value":0,
					"distance":1322.8,
					"amount":100
					}
				]
			},
			"tollways":
				{
				"values":[[0,40,0]],
				"summary":[
					{
						"value":0,
						"distance":1322.8,
						"amount":100
					}
				]
				}
		},
				
		"summary":
			{
				"distance":1322.8,
				"duration":305
			},
		
		"way_points":[0,40]
	},
				
	"geometry":{
		"coordinates":[
			[8.681496,49.41461,114],
			[8.68149,49.414711,114],
			[8.681441,49.415655,114],
			[8.681436,49.415747,114],
			[8.681455,49.415835,114.1],
			[8.681509,49.416087,114.4],
			[8.681642,49.416498,114.7],
			[8.681671,49.416588,114.8],
			[8.681701,49.416684,114.8],
			[8.681875,49.417287,114.8],
			[8.68189,49.417394,114.8],
			[8.681868,49.417475,114.8],
			[8.681865,49.41748,114.8],
			[8.681775,49.417627,114.9],
			[8.681573,49.418169,114.8],
			[8.681536,49.418268,114.7],
			[8.681659,49.418292,114.7],
			[8.683161,49.418548,115.8],
			[8.683276,49.41856,115.8],
			[8.683257,49.418636,115.9],
			[8.683168,49.418995,116.2],
			[8.683157,49.419042,116.3],
			[8.683291,49.419058,116.4],
			[8.684872,49.419242,116.7],
			[8.68501,49.419258,116.7],
			[8.685156,49.419273,116.7],
			[8.686408,49.419402,117.2],
			[8.68651,49.419413,117.3],
			[8.686617,49.419425,117.4],
			[8.686983,49.419461,117.7],
			[8.687101,49.419473,117.8],
			[8.687212,49.419486,118],
			[8.688301,49.419619,118.6],
			[8.688398,49.41963,118.7],
			[8.690104,49.419828,117.8],
			[8.690123,49.419833,117.7],
			[8.689854,49.420216,117.7],
			[8.689652,49.420514,117.9],
			[8.68963,49.42051,118],
			[8.688601,49.420393,118.4],
			[8.687872,49.420318,118.7]
		],
	
		"type":"LineString"
	}
	}
],
		
"bbox":[8.681436,49.41461,114,8.690123,49.420514,118.73],
		
"metadata":{
	"attribution":"openrouteservice.org | OpenStreetMap contributors",
	"service":"routing",
	"timestamp":1587137629525,
	"query":{
	
			"coordinates":[[8.681495,49.41461],[8.687872,49.420318]],
			"profile":"driving-car",
			"preference":"fastest",
			"format":"geojson",
			"units":"m",
			"instructions":true,
			"elevation":true,
			"extra_info":["steepness","surface","waycategory","waytype","tollways"]
	},
	"engine":{
		"version":"6.1.0",
		"build_date":"2020-04-13T02:28:14Z",
		"graph_date":"2020-03-29T23:59:56Z"
	}
}

}
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-f7fd3edd1225> in <module>
#     219                         "format":"geojson",
#     220                         "units":"m",
# --> 221                         "instructions":true,
#     222                         "elevation":true,
#     223                         "extra_info":["steepness","surface","waycategory","waytype","tollways"]
#
# NameError: name 'true' is not defined

# %%
orsWaycategoryDict = {
	0: 'No category',
	1: 'Highway',
	2: 'Steps',
	4: 'Ferry',
	8: 'Unpaved road',
	16: 'Track',
	32: 'Tunnel',
	64: 'Paved road',
	128: 'Ford'
}

# %%
orsWaycategoryDict[4]
# Out:
# 'Ferry'

# %%
orsSteepnessDict = {
	-5: '>16%',
	-4: '12-15%',
	-3: '7-11%',
	-2: '4-6%',
	-1: '1-3%',
	0: '0%',
	1: '1-3%',
	2: '4-6%',
	3: '7-11%',
	4: '12-15%',
	5: '>16%'
}

# %%
orsSteepnessDict[-5]
# Out:
# '>16%'
