# %%
import veroviz as vrv

# %%
OPENWEATHERKEY=''

# %%
vrv.getWeather(location=[42,-78], 
               dataProvider='openweather', 
               dataProviderArgs={'APIkey': ''})
# Out:
# FIXME -- need validation
# ...

# %%
import folium

# %%
folium.TileLayer('cartodbdark_matter').add_to(my_map)

# %%
>>> myNodes = vrv.generateNodes(
...     numNodes        = 4,
...     nodeType        = 'depot', 
...     nodeDistrib     = 'normal', 
...     nodeDistribArgs = {
...         'center' : [42.30, -78.00], 
...         'stdDev' : 1000
...     })
>>> myNodes['elevMeters']
# Out:
# 0    None
# 1    None
# 2    None
# 3    None
# Name: elevMeters, dtype: object

# %%
myMap = vrv.createLeaflet(nodes=myNodes)
myMap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
folium.TileLayer('cartodbdark_matter').add_to(myMap)

# %%
myMap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
x = 'http://maps.openweathermap.org/maps/2.0/weather/TA2/{z}/{x}/{y}?date=1527811200&opacity=0.9&fill_bound=true&appid=8842ea4a54cbba4a48eccf216d507c10'

folium.TileLayer(tiles=x,attr='fdsa').add_to(myMap)

# %%
myMap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
y = 'http://maps.openweathermap.org/maps/2.0/weather/TA2/{z}/{x}/{y}?appid=8842ea4a54cbba4a48eccf216d507c10'
folium.TileLayer(tiles=y,attr='fdsa').add_to(myMap)

# %%
myMap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
folium.LayerControl().add_to(myMap)

# %%
myMap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import folium

# %%
#aaa = 'http://maps.openweathermap.org/maps/2.0/weather/CL/{z}/{x}/{y}?appid=8842ea4a54cbba4a48eccf216d507c10'
#aaa = 'http://maps.openweathermap.org/maps/2.0/weather/PR0/{z}/{x}/{y}?appid=8842ea4a54cbba4a48eccf216d507c10'
clouds = 'https://tile.openweathermap.org/map/clouds_new/{z}/{x}/{y}.png?appid=8842ea4a54cbba4a48eccf216d507c10'
precip = 'https://tile.openweathermap.org/map/precipitation_new/{z}/{x}/{y}.png?appid=8842ea4a54cbba4a48eccf216d507c10'
pressure = 'https://tile.openweathermap.org/map/pressure_new/{z}/{x}/{y}.png?appid=8842ea4a54cbba4a48eccf216d507c10'
wind = 'https://tile.openweathermap.org/map/wind_new/{z}/{x}/{y}.png?appid=8842ea4a54cbba4a48eccf216d507c10'
temp = 'https://tile.openweathermap.org/map/temp_new/{z}/{x}/{y}.png?appid=8842ea4a54cbba4a48eccf216d507c10'


'''
clouds_new
precipitation_new
pressure_new
wind_new
temp_new
''';

ccc = 'https://server.arcgisonline.com/ArcGIS/rest/services/World_Shaded_Relief/MapServer/tile/{z}/{y}/{x}'

# %%
mapObject = folium.Map(
    location=[42, -78], 
    zoom_start=10, 
    tiles=ccc,
    attr='bbb')

mapObject
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
folium.TileLayer(
    tiles=temp,
    attr='bbb',
    # API_key=OPENWEATHERKEY
).add_to(mapObject)

# %%
mapObject
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
type(mapObject)
# Out:
# folium.folium.Map

# %%
mapObject2 = folium.Map(location=[0,0], zoom_start=2)
mapObject2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
mapObject = vrv.addLeafletWeather(APIkey=OPENWEATHERKEY)

# %%
myMap = vrv.addLeafletWeather(mapObject=None, 
                              mapType='wind', 
                              APIkey=OPENWEATHERKEY, 
                              mapFilename=None, 
                              mapBackground='cartodb dark_matter')
myMap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
weatherMaps = {
	'clouds': {
		'tiles': 'https://tile.openweathermap.org/map/clouds_new/{z}/{x}/{y}.png?appid=',
		'attr': 'openweathermap.org'
	},
	
	'precip': { 	
		'tiles': 'https://tile.openweathermap.org/map/precipitation_new/{z}/{x}/{y}.png?appid=',
		'attr': 'openweathermap.org'
	},

	'pressure': { 
		'tiles': 'https://tile.openweathermap.org/map/pressure_new/{z}/{x}/{y}.png?appid=',
		'attr': 'openweathermap.org'
	},
		
	'wind': {
		'tiles': 'https://tile.openweathermap.org/map/wind_new/{z}/{x}/{y}.png?appid=',	
		'attr': 'openweathermap.org'
	},

	'temp': {
		'tiles': 'https://tile.openweathermap.org/map/temp_new/{z}/{x}/{y}.png?appid=',
		'attr': 'openweathermap.org'
	}
}

APIkey = '8842ea4a54cbba4a48eccf216d507c10'

# %%
'''
mapObject3 = folium.Map(
    location=[42, -78], 
    zoom_start=10, 
    tiles=ccc,
    attr='bbb')
'''

mapObject3 = folium.Map(
    location=[42, -78], 
    # zoom_start=10, 
    tiles=None)


folium.TileLayer('cartodb positron', show=True).add_to(mapObject3)
folium.TileLayer('stamenterrain').add_to(mapObject3)
folium.TileLayer('OpenStreetMap', name='OSM').add_to(mapObject3)
folium.TileLayer('cartodb dark_matter').add_to(mapObject3)

folium.LayerControl(collapsed=True).add_to(mapObject3)



# folium.LayerControl().add_to(mapObject3)
# xxx = folium.LayerControl()
# xxx.add_to(mapObject3)

'''
for mapType in weatherMaps:
    folium.TileLayer(
        tiles = '%s%s' % (weatherMaps[mapType]['tiles'], APIkey),
        attr  = weatherMaps[mapType]['attr'],
        name  = mapType,
        overlay = True,
        show    = False
    ).add_to(mapObject3)
'''

#folium.LayerControl().add_to(mapObject3)


mapObject3
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Draw circle:		
folium.Circle([0,0], 
    radius = 50,  
    stroke = True
    ).add_to(mapObject3)

folium.LayerControl().reset()

mapObject3.save('bad.html')
mapObject3
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
mapObject4 = mapObject3
folium.LayerControl().add_to(mapObject4)
mapObject4
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
mapObject3.keep_in_front(xxx)

# %%
xxx.options['autoZIndex'] = False

# %%
>>> mapObject3 = vrv.addLeafletCircle(
...     mapObject = mapObject3,
...     mapFilename = None,
...     # mapBackground = 'OpenStreetMap',
...     mapBoundary = None,
...     zoomStart = 13,
...     center = [43.00154, -78.7871],
...     radius = 2000,
...     text = 'UB',
...     fontSize = 24,
...     fontColor = 'black',
...     popupText = 'Univ. at Buffalo',
...     lineWeight = 6,
...     lineColor = '#ff66ff',
...     lineOpacity = 0.7,
...     lineStyle = 'dotted',
...     fillColor = 'green',
...     fillOpacity = 0.4)
>>> mapObject3
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import folium
from folium.plugins import MarkerCluster

points = [[0,0], [10,10], [15,30], [-15,45]]

map=folium.Map(location=[0, 0], zoom_start=4)
#fg=folium.FeatureGroup(name='My Points', show=False)
#map.add_child(fg)
#marker_cluster = MarkerCluster().add_to(fg)
folium.TileLayer('openstreetmap').add_to(map)
folium.TileLayer('Stamen Terrain').add_to(map)



folium.PolyLine(points, color="black", weight=2.5, opacity=1).add_to(map)

'''
for x in points:
    info = 'test'
    folium.RegularPolygonMarker(location=[x[0], x[1]], popup=info).add_to(marker_cluster)
'''
folium.LayerControl().add_to(map)




map
# map.save("Test.html")
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
>>> bounding = [
...     [42.98355351219673, -78.90518188476564], 
...     [43.04731443361136, -78.83857727050783], 
...     [43.02221961002041, -78.7108612060547], 
...     [42.92777124914475, -78.68957519531251], 
...     [42.866402688514626, -78.75343322753908], 
...     [42.874957707517865, -78.82415771484375], 
...     [42.90111863978987, -78.86878967285158], 
...     [42.92224052343343, -78.8921356201172]]

>>> exampleNodes = vrv.generateNodes(
...     nodeType         = 'customer', 
...     nodeDistrib      = 'normalBB', 
...     nodeDistribArgs  = {
...         'center'         : [42.90, -78.80], 
...         'stdDev'         : 10000,
...         'boundingRegion' : bounding
...     },
...     numNodes         = 3,
...     leafletColor     = 'orange')

# %%
>>> myMap = vrv.createLeaflet(nodes=exampleNodes)
myMap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
>>> exampleArcs = vrv.createArcsFromNodeSeq(
...     nodes   = exampleNodes,
...     nodeSeq = [1, 2, 3])
>>> exampleArcs
# Out:
#   odID objectID   startLat   startLon     endLat     endLon leafletColor  \
# 0    1     None  42.893326 -78.835129  42.922047 -78.771171       orange
# 1    2     None  42.922047 -78.771171  42.924001 -78.854886       orange
#
#   leafletWeight leafletStyle  leafletOpacity useArrows cesiumColor  \
# 0             3        solid             0.8      True      orange
# 1             3        solid             0.8      True      orange
#
#   cesiumWeight cesiumStyle  cesiumOpacity popupText startElevMeters  \
# 0            3       solid            0.8      None            None
# 1            3       solid            0.8      None            None
#
#   endElevMeters
# 0          None
# 1          None

# %%
>>> vrv.createLeaflet(
...     nodes          = exampleNodes,
...     arcs           = exampleArcs,
...     boundingRegion = bounding)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
APIkey = '8842ea4a54cbba4a48eccf216d507c10'

# %%
>>> myMap2 = vrv.addLeafletWeather(mapObject     = None, 
...                               mapType       = 'wind', 
... 						      APIkey        = APIkey, 
... 						      mapFilename   = None, 
...   						      mapBackground = 'cartodb dark_matter')
>>> myMap2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
>>> myMap3 = vrv.addLeafletWeather(mapObject     = myMap, 
...                               mapType       = 'wind', 
... 						      APIkey        = APIkey, 
... 						      mapFilename   = None, 
...   						      mapBackground = 'cartodb positron')
>>> myMap3
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
>>> myMap3 = vrv.addLeafletWeather(mapObject     = myMap3, 
...                               mapType       = 'precip', 
... 						      APIkey        = APIkey, 
... 						      mapFilename   = None, 
...   						      mapBackground = 'cartodb positron')
>>> myMap3
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
>>> vrv.createLeaflet(
...     mapObject = myMap3,
...     nodes          = exampleNodes,
...     arcs           = exampleArcs,
...     boundingRegion = bounding)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
vrv.createLeaflet()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import pandas as pd

# %%
data = {
	'dt': 1587415460, 
	'sunrise': 1587378165, 
	'sunset': 1587427105, 
	'temp': 51.42, 
	'feels_like': 41.92, 
	'pressure': 1003, 
	'humidity': 29, 
	'dew_point': 21.58, 
	'uvi': 5.54, 
	'clouds': 1, 
	'visibility': 16093, 
	'wind_speed': 8.05, 
	'wind_deg': 260, 
	'weather': [
		{
		'id': 800, 
		'main': 'Clear', 
		'description': 'clear sky', 
		'icon': '01d'
		}
	]
}

# %%
pd.DataFrame(data)
# Out:
#            dt     sunrise      sunset   temp  feels_like  pressure  humidity  \
# 0  1587415460  1587378165  1587427105  51.42       41.92      1003        29
#
#    dew_point   uvi  clouds  visibility  wind_speed  wind_deg  \
# 0      21.58  5.54       1       16093        8.05       260
#
#                                              weather
# 0  {'id': 800, 'main': 'Clear', 'description': 'c...

# %%
data = {'lat': 42, 'lon': -78, 'timezone': 'America/New_York', 'current': {'dt': 1587415460, 'sunrise': 1587378165, 'sunset': 1587427105, 'temp': 51.42, 'feels_like': 41.92, 'pressure': 1003, 'humidity': 29, 'dew_point': 21.58, 'uvi': 5.54, 'clouds': 1, 'visibility': 16093, 'wind_speed': 8.05, 'wind_deg': 260, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}]}, 'hourly': [{'dt': 1587412800, 'temp': 51.42, 'feels_like': 44.15, 'pressure': 1003, 'humidity': 29, 'dew_point': 21.58, 'clouds': 1, 'wind_speed': 4.07, 'wind_deg': 268, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}]}, {'dt': 1587416400, 'temp': 48.99, 'feels_like': 41.52, 'pressure': 1004, 'humidity': 36, 'dew_point': 24.22, 'clouds': 1, 'wind_speed': 4.97, 'wind_deg': 248, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}]}, {'dt': 1587420000, 'temp': 46.9, 'feels_like': 39.36, 'pressure': 1005, 'humidity': 43, 'dew_point': 26.33, 'clouds': 0, 'wind_speed': 5.55, 'wind_deg': 244, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}]}, {'dt': 1587423600, 'temp': 42.37, 'feels_like': 35.96, 'pressure': 1005, 'humidity': 58, 'dew_point': 29.05, 'clouds': 0, 'wind_speed': 4.21, 'wind_deg': 249, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}]}, {'dt': 1587427200, 'temp': 34.54, 'feels_like': 28.36, 'pressure': 1005, 'humidity': 67, 'dew_point': 25.56, 'clouds': 0, 'wind_speed': 2.95, 'wind_deg': 267, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}]}, {'dt': 1587430800, 'temp': 31.15, 'feels_like': 24.89, 'pressure': 1006, 'humidity': 74, 'dew_point': 28.65, 'clouds': 0, 'wind_speed': 2.93, 'wind_deg': 307, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}]}, {'dt': 1587434400, 'temp': 29.07, 'feels_like': 24.3, 'pressure': 1006, 'humidity': 80, 'dew_point': 26.82, 'clouds': 0, 'wind_speed': 0.27, 'wind_deg': 162, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}]}, {'dt': 1587438000, 'temp': 29.7, 'feels_like': 23.41, 'pressure': 1006, 'humidity': 78, 'dew_point': 27.36, 'clouds': 27, 'wind_speed': 2.95, 'wind_deg': 178, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}]}, {'dt': 1587441600, 'temp': 29.82, 'feels_like': 22.82, 'pressure': 1005, 'humidity': 78, 'dew_point': 27.37, 'clouds': 42, 'wind_speed': 4.25, 'wind_deg': 182, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}]}, {'dt': 1587445200, 'temp': 30.6, 'feels_like': 23.07, 'pressure': 1004, 'humidity': 75, 'dew_point': 27.64, 'clouds': 54, 'wind_speed': 5.14, 'wind_deg': 179, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}]}, {'dt': 1587448800, 'temp': 31.14, 'feels_like': 23.23, 'pressure': 1003, 'humidity': 74, 'dew_point': 27.63, 'clouds': 61, 'wind_speed': 5.86, 'wind_deg': 183, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}]}, {'dt': 1587452400, 'temp': 30.45, 'feels_like': 22.12, 'pressure': 1001, 'humidity': 75, 'dew_point': 27, 'clouds': 28, 'wind_speed': 6.55, 'wind_deg': 185, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}]}, {'dt': 1587456000, 'temp': 31.69, 'feels_like': 22.53, 'pressure': 1000, 'humidity': 72, 'dew_point': 27.05, 'clouds': 21, 'wind_speed': 8.05, 'wind_deg': 191, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'}]}, {'dt': 1587459600, 'temp': 34.9, 'feels_like': 22.78, 'pressure': 999, 'humidity': 70, 'dew_point': 31.77, 'clouds': 48, 'wind_speed': 13.8, 'wind_deg': 207, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'}], 'rain': {'1h': 0.63}}, {'dt': 1587463200, 'temp': 35.74, 'feels_like': 23.68, 'pressure': 997, 'humidity': 74, 'dew_point': 33.98, 'clouds': 61, 'wind_speed': 14.16, 'wind_deg': 206, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'}], 'rain': {'1h': 0.19}}, {'dt': 1587466800, 'temp': 37.78, 'feels_like': 26.82, 'pressure': 996, 'humidity': 77, 'dew_point': 36.66, 'clouds': 69, 'wind_speed': 12.93, 'wind_deg': 208, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}]}, {'dt': 1587470400, 'temp': 38.55, 'feels_like': 27.88, 'pressure': 996, 'humidity': 76, 'dew_point': 37.15, 'clouds': 74, 'wind_speed': 12.53, 'wind_deg': 216, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10d'}], 'rain': {'1h': 0.31}}, {'dt': 1587474000, 'temp': 38.17, 'feels_like': 25.95, 'pressure': 997, 'humidity': 78, 'dew_point': 37.62, 'clouds': 100, 'wind_speed': 15.35, 'wind_deg': 263, 'weather': [{'id': 501, 'main': 'Rain', 'description': 'moderate rain', 'icon': '10d'}], 'rain': {'1h': 3}}, {'dt': 1587477600, 'temp': 33.76, 'feels_like': 19.74, 'pressure': 998, 'humidity': 79, 'dew_point': 33.4, 'clouds': 100, 'wind_speed': 17.58, 'wind_deg': 295, 'weather': [{'id': 601, 'main': 'Snow', 'description': 'snow', 'icon': '13d'}], 'snow': {'1h': 0.88}}, {'dt': 1587481200, 'temp': 33.28, 'feels_like': 20.23, 'pressure': 1000, 'humidity': 72, 'dew_point': 30.76, 'clouds': 100, 'wind_speed': 15.26, 'wind_deg': 289, 'weather': [{'id': 600, 'main': 'Snow', 'description': 'light snow', 'icon': '13d'}], 'snow': {'1h': 0.19}}, {'dt': 1587484800, 'temp': 34.32, 'feels_like': 20.35, 'pressure': 1001, 'humidity': 66, 'dew_point': 28.67, 'clouds': 100, 'wind_speed': 16.67, 'wind_deg': 281, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}]}, {'dt': 1587488400, 'temp': 35.06, 'feels_like': 18.79, 'pressure': 1002, 'humidity': 63, 'dew_point': 27.79, 'clouds': 100, 'wind_speed': 20.69, 'wind_deg': 279, 'weather': [{'id': 600, 'main': 'Snow', 'description': 'light snow', 'icon': '13d'}], 'snow': {'1h': 0.25}}, {'dt': 1587492000, 'temp': 34.21, 'feels_like': 18.1, 'pressure': 1002, 'humidity': 65, 'dew_point': 26.55, 'clouds': 100, 'wind_speed': 20.4, 'wind_deg': 280, 'weather': [{'id': 600, 'main': 'Snow', 'description': 'light snow', 'icon': '13d'}], 'snow': {'1h': 0.13}}, {'dt': 1587495600, 'temp': 33.87, 'feels_like': 18, 'pressure': 1003, 'humidity': 64, 'dew_point': 23.74, 'clouds': 100, 'wind_speed': 19.84, 'wind_deg': 282, 'weather': [{'id': 600, 'main': 'Snow', 'description': 'light snow', 'icon': '13d'}], 'snow': {'1h': 0.13}}, {'dt': 1587499200, 'temp': 33.6, 'feels_like': 17.87, 'pressure': 1004, 'humidity': 63, 'dew_point': 22.24, 'clouds': 100, 'wind_speed': 19.48, 'wind_deg': 284, 'weather': [{'id': 600, 'main': 'Snow', 'description': 'light snow', 'icon': '13d'}], 'snow': {'1h': 0.13}}, {'dt': 1587502800, 'temp': 32.76, 'feels_like': 16.97, 'pressure': 1005, 'humidity': 65, 'dew_point': 21.56, 'clouds': 100, 'wind_speed': 19.57, 'wind_deg': 283, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}]}, {'dt': 1587506400, 'temp': 31.19, 'feels_like': 15.91, 'pressure': 1006, 'humidity': 69, 'dew_point': 21.83, 'clouds': 100, 'wind_speed': 18.63, 'wind_deg': 284, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}]}, {'dt': 1587510000, 'temp': 29.66, 'feels_like': 15.93, 'pressure': 1007, 'humidity': 73, 'dew_point': 21.63, 'clouds': 100, 'wind_speed': 15.86, 'wind_deg': 285, 'weather': [{'id': 600, 'main': 'Snow', 'description': 'light snow', 'icon': '13d'}], 'snow': {'1h': 0.13}}, {'dt': 1587513600, 'temp': 25.83, 'feels_like': 13.91, 'pressure': 1008, 'humidity': 89, 'dew_point': 24.96, 'clouds': 100, 'wind_speed': 12.82, 'wind_deg': 280, 'weather': [{'id': 600, 'main': 'Snow', 'description': 'light snow', 'icon': '13n'}], 'snow': {'1h': 0.19}}, {'dt': 1587517200, 'temp': 26.49, 'feels_like': 13.06, 'pressure': 1009, 'humidity': 86, 'dew_point': 24.73, 'clouds': 100, 'wind_speed': 15.48, 'wind_deg': 292, 'weather': [{'id': 601, 'main': 'Snow', 'description': 'snow', 'icon': '13n'}], 'snow': {'1h': 0.56}}, {'dt': 1587520800, 'temp': 26.24, 'feels_like': 14.07, 'pressure': 1010, 'humidity': 83, 'dew_point': 20.07, 'clouds': 100, 'wind_speed': 13.04, 'wind_deg': 291, 'weather': [{'id': 600, 'main': 'Snow', 'description': 'light snow', 'icon': '13n'}], 'snow': {'1h': 0.19}}, {'dt': 1587524400, 'temp': 23.02, 'feels_like': 11.59, 'pressure': 1010, 'humidity': 89, 'dew_point': 18.23, 'clouds': 86, 'wind_speed': 11.48, 'wind_deg': 289, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}]}, {'dt': 1587528000, 'temp': 22.08, 'feels_like': 9.84, 'pressure': 1011, 'humidity': 91, 'dew_point': 18.93, 'clouds': 65, 'wind_speed': 12.84, 'wind_deg': 288, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}]}, {'dt': 1587531600, 'temp': 22.42, 'feels_like': 9.66, 'pressure': 1011, 'humidity': 92, 'dew_point': 20.52, 'clouds': 72, 'wind_speed': 13.87, 'wind_deg': 291, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}]}, {'dt': 1587535200, 'temp': 22.39, 'feels_like': 9.12, 'pressure': 1012, 'humidity': 91, 'dew_point': 19.36, 'clouds': 76, 'wind_speed': 14.7, 'wind_deg': 293, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}]}, {'dt': 1587538800, 'temp': 21.74, 'feels_like': 8.91, 'pressure': 1011, 'humidity': 90, 'dew_point': 18.14, 'clouds': 100, 'wind_speed': 13.78, 'wind_deg': 293, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}]}, {'dt': 1587542400, 'temp': 21.6, 'feels_like': 9.05, 'pressure': 1012, 'humidity': 90, 'dew_point': 17.62, 'clouds': 100, 'wind_speed': 13.27, 'wind_deg': 291, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}]}, {'dt': 1587546000, 'temp': 21.36, 'feels_like': 8.53, 'pressure': 1013, 'humidity': 90, 'dew_point': 17.67, 'clouds': 100, 'wind_speed': 13.73, 'wind_deg': 287, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}]}, {'dt': 1587549600, 'temp': 20.82, 'feels_like': 7.99, 'pressure': 1014, 'humidity': 91, 'dew_point': 17.74, 'clouds': 100, 'wind_speed': 13.69, 'wind_deg': 286, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}]}, {'dt': 1587553200, 'temp': 21.36, 'feels_like': 8.15, 'pressure': 1015, 'humidity': 90, 'dew_point': 17.49, 'clouds': 100, 'wind_speed': 14.41, 'wind_deg': 287, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}]}, {'dt': 1587556800, 'temp': 22.98, 'feels_like': 9.46, 'pressure': 1015, 'humidity': 88, 'dew_point': 17.46, 'clouds': 100, 'wind_speed': 15.12, 'wind_deg': 290, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}]}, {'dt': 1587560400, 'temp': 25.32, 'feels_like': 11.82, 'pressure': 1015, 'humidity': 84, 'dew_point': 17.64, 'clouds': 100, 'wind_speed': 15.3, 'wind_deg': 291, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}]}, {'dt': 1587564000, 'temp': 28.02, 'feels_like': 14.34, 'pressure': 1015, 'humidity': 75, 'dew_point': 17.19, 'clouds': 100, 'wind_speed': 15.61, 'wind_deg': 291, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}]}, {'dt': 1587567600, 'temp': 30.72, 'feels_like': 17.04, 'pressure': 1015, 'humidity': 67, 'dew_point': 17.04, 'clouds': 95, 'wind_speed': 15.59, 'wind_deg': 291, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}]}, {'dt': 1587571200, 'temp': 33.24, 'feels_like': 19.36, 'pressure': 1015, 'humidity': 60, 'dew_point': 16.84, 'clouds': 71, 'wind_speed': 15.93, 'wind_deg': 291, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}]}, {'dt': 1587574800, 'temp': 35.22, 'feels_like': 21.24, 'pressure': 1015, 'humidity': 56, 'dew_point': 16.84, 'clouds': 57, 'wind_speed': 16.15, 'wind_deg': 291, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}]}, {'dt': 1587578400, 'temp': 36.48, 'feels_like': 22.82, 'pressure': 1014, 'humidity': 54, 'dew_point': 17.38, 'clouds': 47, 'wind_speed': 15.64, 'wind_deg': 289, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}]}, {'dt': 1587582000, 'temp': 37.38, 'feels_like': 24.1, 'pressure': 1014, 'humidity': 52, 'dew_point': 18.1, 'clouds': 0, 'wind_speed': 14.97, 'wind_deg': 289, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}]}], 'daily': [{'dt': 1587402000, 'sunrise': 1587378165, 'sunset': 1587427105, 'temp': {'day': 51.42, 'min': 30.07, 'max': 51.42, 'night': 31.19, 'eve': 35.8, 'morn': 51.42}, 'feels_like': {'day': 44.06, 'night': 23.29, 'eve': 29.64, 'morn': 44.06}, 'pressure': 1003, 'humidity': 29, 'dew_point': 21.58, 'wind_speed': 4.23, 'wind_deg': 304, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'clouds': 1, 'uvi': 5.54}, {'dt': 1587488400, 'sunrise': 1587464475, 'sunset': 1587513572, 'temp': {'day': 34.21, 'min': 22.39, 'max': 38.55, 'night': 22.39, 'eve': 25.83, 'morn': 38.55}, 'feels_like': {'day': 18.1, 'night': 9.12, 'eve': 13.91, 'morn': 27.88}, 'pressure': 1002, 'humidity': 65, 'dew_point': 26.55, 'wind_speed': 20.4, 'wind_deg': 280, 'weather': [{'id': 601, 'main': 'Snow', 'description': 'snow', 'icon': '13d'}], 'clouds': 100, 'rain': 0.56, 'snow': 6.07, 'uvi': 5.94}, {'dt': 1587574800, 'sunrise': 1587550786, 'sunset': 1587600040, 'temp': {'day': 36.48, 'min': 22.98, 'max': 36.66, 'night': 25.81, 'eve': 27.91, 'morn': 22.98}, 'feels_like': {'day': 22.82, 'night': 19.33, 'eve': 18.93, 'morn': 9.46}, 'pressure': 1014, 'humidity': 54, 'dew_point': 17.38, 'wind_speed': 15.64, 'wind_deg': 289, 'weather': [{'id': 600, 'main': 'Snow', 'description': 'light snow', 'icon': '13d'}], 'clouds': 47, 'snow': 0.44, 'uvi': 6.56}, {'dt': 1587661200, 'sunrise': 1587637098, 'sunset': 1587686507, 'temp': {'day': 50.63, 'min': 32.85, 'max': 50.63, 'night': 39.54, 'eve': 40.44, 'morn': 32.85}, 'feels_like': {'day': 40.5, 'night': 32.13, 'eve': 33.37, 'morn': 26.76}, 'pressure': 1009, 'humidity': 54, 'dew_point': 39.83, 'wind_speed': 12.35, 'wind_deg': 168, 'weather': [{'id': 501, 'main': 'Rain', 'description': 'moderate rain', 'icon': '10d'}], 'clouds': 100, 'rain': 9.39, 'uvi': 6.17}, {'dt': 1587747600, 'sunrise': 1587723410, 'sunset': 1587772974, 'temp': {'day': 44.67, 'min': 31.39, 'max': 48.18, 'night': 32.16, 'eve': 37.78, 'morn': 38.5}, 'feels_like': {'day': 35.91, 'night': 24.26, 'eve': 30.9, 'morn': 29.82}, 'pressure': 1012, 'humidity': 63, 'dew_point': 38.17, 'wind_speed': 9.44, 'wind_deg': 345, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'clouds': 100, 'uvi': 6.17}, {'dt': 1587834000, 'sunrise': 1587809724, 'sunset': 1587859441, 'temp': {'day': 43.38, 'min': 39.63, 'max': 51.69, 'night': 41.77, 'eve': 51.69, 'morn': 39.63}, 'feels_like': {'day': 31.73, 'night': 36.23, 'eve': 44.89, 'morn': 28.99}, 'pressure': 1005, 'humidity': 78, 'dew_point': 42.62, 'wind_speed': 15.75, 'wind_deg': 145, 'weather': [{'id': 502, 'main': 'Rain', 'description': 'heavy intensity rain', 'icon': '10d'}], 'clouds': 100, 'rain': 19.88, 'uvi': 6.09}, {'dt': 1587920400, 'sunrise': 1587896039, 'sunset': 1587945908, 'temp': {'day': 38.82, 'min': 33.31, 'max': 41.97, 'night': 33.31, 'eve': 37.26, 'morn': 41.97}, 'feels_like': {'day': 31.55, 'night': 22.05, 'eve': 29.91, 'morn': 32.94}, 'pressure': 1001, 'humidity': 71, 'dew_point': 35.92, 'wind_speed': 6.11, 'wind_deg': 238, 'weather': [{'id': 600, 'main': 'Snow', 'description': 'light snow', 'icon': '13d'}], 'clouds': 87, 'rain': 2.76, 'snow': 0.25, 'uvi': 5.7}, {'dt': 1588006800, 'sunrise': 1587982355, 'sunset': 1588032375, 'temp': {'day': 33.6, 'min': 28.65, 'max': 33.6, 'night': 31.05, 'eve': 30.94, 'morn': 28.65}, 'feels_like': {'day': 22.39, 'night': 22.26, 'eve': 20.89, 'morn': 17.6}, 'pressure': 1014, 'humidity': 68, 'dew_point': 29.07, 'wind_speed': 11.79, 'wind_deg': 323, 'weather': [{'id': 601, 'main': 'Snow', 'description': 'snow', 'icon': '13d'}], 'clouds': 100, 'snow': 4.43, 'uvi': 5.98}]}

# %%
data['current']
# Out:
# {'dt': 1587415460,
#  'sunrise': 1587378165,
#  'sunset': 1587427105,
#  'temp': 51.42,
#  'feels_like': 41.92,
#  'pressure': 1003,
#  'humidity': 29,
#  'dew_point': 21.58,
#  'uvi': 5.54,
#  'clouds': 1,
#  'visibility': 16093,
#  'wind_speed': 8.05,
#  'wind_deg': 260,
#  'weather': [{'id': 800,
#    'main': 'Clear',
#    'description': 'clear sky',
#    'icon': '01d'}]}

# %%
id = 1

x = []

subDict = {}
subDict['id']       = id
subDict['lat']      = data['lat'] 
subDict['lon']      = data['lon'] 
subDict['timezone'] = data['timezone']
subDict['class']    = 'current'
for key in data['current']:
    if (key == 'weather'):
        for subkey in data['current']['weather'][0]:
            subDict['weather_' + subkey] = data['current']['weather'][0][subkey]
    else:
        subDict[key] = data['current'][key]
x.append(subDict)

for i in range(0, len(data['hourly'])):
    subDict = {}
    subDict['id']       = id
    subDict['lat']      = data['lat'] 
    subDict['lon']      = data['lon'] 
    subDict['timezone'] = data['timezone']
    subDict['class']    = 'hourly'
    for key in data['hourly'][i]:
        if (key == 'weather'):
            for subkey in data['hourly'][i]['weather'][0]:
                subDict['weather_' + subkey] = data['hourly'][i]['weather'][0][subkey]

        else:
            subDict[key] = data['hourly'][i][key]
    x.append(subDict)

for i in range(0, len(data['daily'])):
    subDict = {}
    subDict['id']       = id
    subDict['lat']      = data['lat'] 
    subDict['lon']      = data['lon'] 
    subDict['timezone'] = data['timezone']
    subDict['class']    = 'daily'
    for key in data['daily'][i]:
        if (key == 'weather'):
            for subkey in data['daily'][i]['weather'][0]:
                subDict['weather_' + subkey] = data['daily'][i]['weather'][0][subkey]

        elif (key == 'temp'):
            for subkey in data['daily'][i]['temp']:
                subDict['temp_' + subkey] = data['daily'][i]['temp'][subkey]

        elif (key == 'feels_like'):
            for subkey in data['daily'][i]['feels_like']:
                subDict['feels_like_' + subkey] = data['daily'][i]['feels_like'][subkey]

        else:
            subDict[key] = data['daily'][i][key]
    x.append(subDict)

    
x
# Out:
# [{'id': 1,
#   'lat': 42,
#   'lon': -78,
#   'timezone': 'America/New_York',
#   'class': 'current',
#   'dt': 1587415460,
#   'sunrise': 1587378165,
#   'sunset': 1587427105,
#   'temp': 51.42,
#   'feels_like': 41.92,
#   'pressure': 1003,
#   'humidity': 29,
#   'dew_point': 21.58,
#   'uvi': 5.54,
#   'clouds': 1,
#   'visibility': 16093,
#   'wind_speed': 8.05,
#   'wind_deg': 260,
#   'weather_id': 800,
#   'weather_main': 'Clear',
#   'weather_description': 'clear sky',
#   'weather_icon': '01d'},
#  {'id': 1,
#   'lat': 42,
#   'lon': -78,
#   'timezone': 'America/New_York',
#   'class': 'hourly',
#   'dt': 1587412800,
#   'temp': 51.42,
#   'feels_like': 44.15,
#   'pressure': 1003,
#   'humidity': 29,
#   'dew_point': 21.58,
#   'clouds': 1,
#   'wind_speed': 4.07,
#   'wind_deg': 268,
#   'weather_id': 800,
#   'weather_main': 'Clear',
#   'weather_description': 'clear sky',
#   'weather_icon': '01d'},
#  {'id': 1,
#   'lat': 42,
#   'lon': -78,
# ...

# %%
df = pd.DataFrame(x)

df['dt']      = pd.to_datetime(df['dt'], unit='s', errors='ignore')
df['sunrise'] = pd.to_datetime(df['sunrise'], unit='s', errors='ignore')
df['sunset']  = pd.to_datetime(df['sunset'], unit='s', errors='ignore')

# %%
df['dt']      = pd.to_datetime(df['dt'], unit='s')
df['sunrise'] = pd.to_datetime(df['sunrise'], unit='s', errors='ignore')
df['sunset'] = pd.to_datetime(df['sunset'], unit='s', errors='ignore')

df[['dt', 'sunrise', 'sunset']]
# Out:
#                     dt             sunrise              sunset
# 0  2020-04-20 20:44:20 2020-04-20 10:22:45 2020-04-20 23:58:25
# 1  2020-04-20 20:00:00                 NaT                 NaT
# 2  2020-04-20 21:00:00                 NaT                 NaT
# 3  2020-04-20 22:00:00                 NaT                 NaT
# 4  2020-04-20 23:00:00                 NaT                 NaT
# 5  2020-04-21 00:00:00                 NaT                 NaT
# 6  2020-04-21 01:00:00                 NaT                 NaT
# 7  2020-04-21 02:00:00                 NaT                 NaT
# 8  2020-04-21 03:00:00                 NaT                 NaT
# 9  2020-04-21 04:00:00                 NaT                 NaT
# 10 2020-04-21 05:00:00                 NaT                 NaT
# 11 2020-04-21 06:00:00                 NaT                 NaT
# 12 2020-04-21 07:00:00                 NaT                 NaT
# 13 2020-04-21 08:00:00                 NaT                 NaT
# ...

# %%
pd.to_datetime(df[['dt', 'sunrise']], unit='s', errors='ignore')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-30-55aa28b01caf> in <module>
# ----> 1 pd.to_datetime(df[['dt', 'sunrise']], unit='s', errors='ignore')
#
# /anaconda3/envs/vrv3/lib/python3.7/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     206                 else:
#     207                     kwargs[new_arg_name] = new_arg_value
# --> 208             return func(*args, **kwargs)
#     209
#     210         return wrapper
#
# /anaconda3/envs/vrv3/lib/python3.7/site-packages/pandas/core/tools/datetimes.py in to_datetime(arg, errors, dayfirst, yearfirst, utc, box, format, exact, unit, infer_datetime_format, origin, cache)
#     776             result = arg._constructor(values, index=arg.index, name=arg.name)
#     777     elif isinstance(arg, (ABCDataFrame, abc.MutableMapping)):
# ...
