# %%
import veroviz as vrv

import os
import pandas as pd

# %%
vInfo = { 
    'Army Truck': {'myObjectID': 'Army Truck', 'myModel': 'veroviz/models/ArmyTruck.gltf', 'myCesiumColor': 'Cesium.Color.RED', 'myLeafletColor':'red', 'myArcStyle':'solid', 'modelScale': 10,  'modelMinPxSize': 10,
    'alt': 0},
    
    
    'Blue Car': {'myObjectID': 'Blue Car', 'myModel': 'veroviz/models/car_blue.gltf', 'myCesiumColor': 'Cesium.Color.RED', 'myLeafletColor':'red', 'myArcStyle':'solid', 'modelScale': 100,  'modelMinPxSize': 100,
    'alt': 0},
    'Blue Car small v3': {'myObjectID': 'Blue Car Small v3', 'myModel': 'veroviz/models/car_blue-small_v3.gltf', 'myCesiumColor': 'Cesium.Color.RED', 'myLeafletColor':'red', 'myArcStyle':'solid', 'modelScale': 100,  'modelMinPxSize': 100,
    'alt': 0},
    'Blue Car small v3 - 90': {'myObjectID': 'Blue Car Small v3 -90', 'myModel': 'veroviz/models/car_blue-small_v3_rotate90.gltf', 'myCesiumColor': 'Cesium.Color.RED', 'myLeafletColor':'red', 'myArcStyle':'solid', 'modelScale': 100,  'modelMinPxSize': 100,
    'alt': 0},
    'Car carrier': {'myObjectID': 'Car carrier', 'myModel': 'veroviz/models/car_carrier.gltf', 'myCesiumColor': 'Cesium.Color.RED', 'myLeafletColor':'red', 'myArcStyle':'solid', 'modelScale': 100,  'modelMinPxSize': 100,
    'alt': 0},
    'Car carrier7': {'myObjectID': 'Car carrier7', 'myModel': 'veroviz/models/car_carrier7.gltf', 'myCesiumColor': 'Cesium.Color.RED', 'myLeafletColor':'red', 'myArcStyle':'solid', 'modelScale': 100,  'modelMinPxSize': 100,
    'alt': 0},
    'Gray Car': {'myObjectID': 'Gray Car', 'myModel': 'veroviz/models/car_gray.gltf', 'myCesiumColor': 'Cesium.Color.RED', 'myLeafletColor':'red', 'myArcStyle':'solid', 'modelScale': 100,  'modelMinPxSize': 100,
    'alt': 0},
    'Green Car': {'myObjectID': 'Green Car', 'myModel': 'veroviz/models/car_green.gltf', 'myCesiumColor': 'Cesium.Color.RED', 'myLeafletColor':'red', 'myArcStyle':'solid', 'modelScale': 100,  'modelMinPxSize': 100,
    'alt': 0},
    'Orange Car': {'myObjectID': 'Orange Car', 'myModel': 'veroviz/models/car_orange.gltf', 'myCesiumColor': 'Cesium.Color.RED', 'myLeafletColor':'red', 'myArcStyle':'solid', 'modelScale': 100,  'modelMinPxSize': 100,
    'alt': 0},
    'Pink Car': {'myObjectID': 'Pink Car', 'myModel': 'veroviz/models/car_pink.gltf', 'myCesiumColor': 'Cesium.Color.RED', 'myLeafletColor':'red', 'myArcStyle':'solid', 'modelScale': 100,  'modelMinPxSize': 100,
    'alt': 0},
    'Red Car': {'myObjectID': 'Red Car', 'myModel': 'veroviz/models/car_red.gltf', 'myCesiumColor': 'Cesium.Color.RED', 'myLeafletColor':'red', 'myArcStyle':'solid', 'modelScale': 100,  'modelMinPxSize': 100,
    'alt': 0},
    'Red Car v3': {'myObjectID': 'Red Car v3', 'myModel': 'veroviz/models/car_red-small_v3.gltf', 'myCesiumColor': 'Cesium.Color.RED', 'myLeafletColor':'red', 'myArcStyle':'solid', 'modelScale': 100,  'modelMinPxSize': 100,
    'alt': 0},
    'Red Car v3 90': {'myObjectID': 'Red Car v3 90', 'myModel': 'veroviz/models/car_red-small_v3_rotate90.gltf', 'myCesiumColor': 'Cesium.Color.RED', 'myLeafletColor':'red', 'myArcStyle':'solid', 'modelScale': 100,  'modelMinPxSize': 100,
    'alt': 0},
    'White Car': {'myObjectID': 'White Car', 'myModel': 'veroviz/models/car_white.gltf', 'myCesiumColor': 'Cesium.Color.RED', 'myLeafletColor':'red', 'myArcStyle':'solid', 'modelScale': 100,  'modelMinPxSize': 100,
    'alt': 0},
    'White Car small': {'myObjectID': 'White Car small', 'myModel': 'veroviz/models/car_white-small.gltf', 'myCesiumColor': 'Cesium.Color.RED', 'myLeafletColor':'red', 'myArcStyle':'solid', 'modelScale': 100,  'modelMinPxSize': 100,
    'alt': 0},
    'White Car v3 90': {'myObjectID': 'White Car v3 90', 'myModel': 'veroviz/models/car_white-small_rotate90.gltf', 'myCesiumColor': 'Cesium.Color.RED', 'myLeafletColor':'red', 'myArcStyle':'solid', 'modelScale': 100,  'modelMinPxSize': 100,
    'alt': 0},
    'Yellow Car': {'myObjectID': 'Yellow Car', 'myModel': 'veroviz/models/car_yellow.gltf', 'myCesiumColor': 'Cesium.Color.RED', 'myLeafletColor':'red', 'myArcStyle':'solid', 'modelScale': 100,  'modelMinPxSize': 100,
    'alt': 0},
    'Yellow Car small': {'myObjectID': 'Yellow Car small', 'myModel': 'veroviz/models/car_yellow-small.gltf', 'myCesiumColor': 'Cesium.Color.RED', 'myLeafletColor':'red', 'myArcStyle':'solid', 'modelScale': 100,  'modelMinPxSize': 100,
    'alt': 0},
    'Yellow Car v3 90': {'myObjectID': 'Yellow Car v3 90', 'myModel': 'veroviz/models/car_yellow-small_rotate90.gltf', 'myCesiumColor': 'Cesium.Color.RED', 'myLeafletColor':'red', 'myArcStyle':'solid', 'modelScale': 100,  'modelMinPxSize': 100,
    'alt': 0},
    'Package': {'myObjectID': 'Package', 'myModel': 'veroviz/models/package.gltf', 'myCesiumColor': 'Cesium.Color.RED', 'myLeafletColor':'red', 'myArcStyle':'solid', 'modelScale': 100,  'modelMinPxSize': 100,
    'alt': 0},
    'UB Truck': {'myObjectID': 'UB Truck', 'myModel': 'veroviz/models/ub_truck.gltf', 'myCesiumColor': 'Cesium.Color.RED', 'myLeafletColor':'red', 'myArcStyle':'solid', 'modelScale': 100,  'modelMinPxSize': 100,
    'alt': 0},
    'UB Truck 1': {'myObjectID': 'UB Truck 1', 'myModel': 'veroviz/models/ub_truck_1.gltf', 'myCesiumColor': 'Cesium.Color.RED', 'myLeafletColor':'red', 'myArcStyle':'solid', 'modelScale': 100,  'modelMinPxSize': 100,
    'alt': 0},
    'UB Truck 2': {'myObjectID': 'UB Truck 2', 'myModel': 'veroviz/models/ub_truck_2.gltf', 'myCesiumColor': 'Cesium.Color.RED', 'myLeafletColor':'red', 'myArcStyle':'solid', 'modelScale': 100,  'modelMinPxSize': 100,
    'alt': 0},
    'UB Truck 3': {'myObjectID': 'UB Truck 3', 'myModel': 'veroviz/models/ub_truck_3.gltf', 'myCesiumColor': 'Cesium.Color.RED', 'myLeafletColor':'red', 'myArcStyle':'solid', 'modelScale': 100,  'modelMinPxSize': 100,
    'alt': 0},
    'UB Truck 4': {'myObjectID': 'UB Truck 4', 'myModel': 'veroviz/models/ub_truck_4.gltf', 'myCesiumColor': 'Cesium.Color.RED', 'myLeafletColor':'red', 'myArcStyle':'solid', 'modelScale': 100,  'modelMinPxSize': 100,
    'alt': 0},
    'UB Truck 5': {'myObjectID': 'UB Truck 5', 'myModel': 'veroviz/models/ub_truck_5.gltf', 'myCesiumColor': 'Cesium.Color.RED', 'myLeafletColor':'red', 'myArcStyle':'solid', 'modelScale': 100,  'modelMinPxSize': 100,
    'alt': 0},
    'UB Truck and Iris': {'myObjectID': 'UB Truck and Iris', 'myModel': 'veroviz/models/ub_truck_plus_iris.gltf', 'myCesiumColor': 'Cesium.Color.RED', 'myLeafletColor':'red', 'myArcStyle':'solid', 'modelScale': 100,  'modelMinPxSize': 100,
    'alt': 0},
    'UPS Truck': {'myObjectID': 'UPS Truck', 'myModel': 'veroviz/models/ups_truck.gltf', 'myCesiumColor': 'Cesium.Color.RED', 'myLeafletColor':'red', 'myArcStyle':'solid', 'modelScale': 100,  'modelMinPxSize': 100,
    'alt': 0},
    
    'Blue Box': {'myObjectID': 'Blue Box', 'myModel': 'veroviz/models/box_blue.gltf', 'myCesiumColor': 'Cesium.Color.RED', 'myLeafletColor':'red', 'myArcStyle':'solid', 'modelScale': 100,  'modelMinPxSize': 100,
    'alt': 0},
    'Blue Box Centered': {'myObjectID': 'Blue Box Centered', 'myModel': 'veroviz/models/box_blue_centered.gltf', 'myCesiumColor': 'Cesium.Color.RED', 'myLeafletColor':'red', 'myArcStyle':'solid', 'modelScale': 100,  'modelMinPxSize': 100,
    'alt': 0},
    'Brown Box Centered': {'myObjectID': 'Brown Box Centered', 'myModel': 'veroviz/models/box_brown_centered.gltf', 'myCesiumColor': 'Cesium.Color.RED', 'myLeafletColor':'red', 'myArcStyle':'solid', 'modelScale': 100,  'modelMinPxSize': 100,
    'alt': 0},
    'Gray Box Centered': {'myObjectID': 'Gray Box Centered', 'myModel': 'veroviz/models/box_gray_centered.gltf', 'myCesiumColor': 'Cesium.Color.RED', 'myLeafletColor':'red', 'myArcStyle':'solid', 'modelScale': 100,  'modelMinPxSize': 100,
    'alt': 0},
    'Green Box Centered': {'myObjectID': 'Green Box Centered', 'myModel': 'veroviz/models/box_green_centered.gltf', 'myCesiumColor': 'Cesium.Color.RED', 'myLeafletColor':'red', 'myArcStyle':'solid', 'modelScale': 100,  'modelMinPxSize': 100,
    'alt': 0},
    'Orange Box Centered': {'myObjectID': 'Orange Box Centered', 'myModel': 'veroviz/models/box_orange_centered.gltf', 'myCesiumColor': 'Cesium.Color.RED', 'myLeafletColor':'red', 'myArcStyle':'solid', 'modelScale': 100,  'modelMinPxSize': 100,
    'alt': 0},
    'Red Box Centered': {'myObjectID': 'Red Box Centered', 'myModel': 'veroviz/models/box_red_centered.gltf', 'myCesiumColor': 'Cesium.Color.RED', 'myLeafletColor':'red', 'myArcStyle':'solid', 'modelScale': 100,  'modelMinPxSize': 100,
    'alt': 0},
    'Yellow Box': {'myObjectID': 'Yellow Box', 'myModel': 'veroviz/models/box_yellow.gltf', 'myCesiumColor': 'Cesium.Color.RED', 'myLeafletColor':'red', 'myArcStyle':'solid', 'modelScale': 100,  'modelMinPxSize': 100,
    'alt': 0},
    'Yellow Box Centered': {'myObjectID': 'Yellow Box Centered', 'myModel': 'veroviz/models/box_yellow_centered.gltf', 'myCesiumColor': 'Cesium.Color.RED', 'myLeafletColor':'red', 'myArcStyle':'solid', 'modelScale': 100,  'modelMinPxSize': 100,
    'alt': 0},
    
    
    'Black Husky': {'myObjectID': 'Black Husky', 'myModel': 'veroviz/models/husky_black.gltf', 'myCesiumColor': 'Cesium.Color.RED', 'myLeafletColor':'red', 'myArcStyle':'solid', 'modelScale': 100,  'modelMinPxSize': 100,
    'alt': 0},
    'Blue Husky': {'myObjectID': 'Blue Husky', 'myModel': 'veroviz/models/husky_blue.gltf', 'myCesiumColor': 'Cesium.Color.RED', 'myLeafletColor':'red', 'myArcStyle':'solid', 'modelScale': 100,  'modelMinPxSize': 100,
    'alt': 0},
    'Green Husky': {'myObjectID': 'Green Husky', 'myModel': 'veroviz/models/husky_green.gltf', 'myCesiumColor': 'Cesium.Color.RED', 'myLeafletColor':'red', 'myArcStyle':'solid', 'modelScale': 100,  'modelMinPxSize': 100,
    'alt': 0},
    'Orange Husky': {'myObjectID': 'Orange Husky', 'myModel': 'veroviz/models/husky_orange.gltf', 'myCesiumColor': 'Cesium.Color.RED', 'myLeafletColor':'red', 'myArcStyle':'solid', 'modelScale': 100,  'modelMinPxSize': 100,
    'alt': 0},
    'Purple Husky': {'myObjectID': 'Purple Husky', 'myModel': 'veroviz/models/husky_purple.gltf', 'myCesiumColor': 'Cesium.Color.RED', 'myLeafletColor':'red', 'myArcStyle':'solid', 'modelScale': 100,  'modelMinPxSize': 100,
    'alt': 0},
    'Red Husky': {'myObjectID': 'Red Husky', 'myModel': 'veroviz/models/husky_red.gltf', 'myCesiumColor': 'Cesium.Color.RED', 'myLeafletColor':'red', 'myArcStyle':'solid', 'modelScale': 100,  'modelMinPxSize': 100,
    'alt': 0},
    'White Husky': {'myObjectID': 'White Husky', 'myModel': 'veroviz/models/husky_white.gltf', 'myCesiumColor': 'Cesium.Color.RED', 'myLeafletColor':'red', 'myArcStyle':'solid', 'modelScale': 100,  'modelMinPxSize': 100,
    'alt': 0},
    'Yellow Husky': {'myObjectID': 'Yellow Husky', 'myModel': 'veroviz/models/husky_yellow.gltf', 'myCesiumColor': 'Cesium.Color.RED', 'myLeafletColor':'red', 'myArcStyle':'solid', 'modelScale': 100,  'modelMinPxSize': 100,
    'alt': 0},
    'Black Husky': {'myObjectID': 'Black Husky', 'myModel': 'veroviz/models/husky_black.gltf', 'myCesiumColor': 'Cesium.Color.RED', 'myLeafletColor':'red', 'myArcStyle':'solid', 'modelScale': 100,  'modelMinPxSize': 100,
    'alt': 0},
    
    
    'Drone': {'myObjectID': 'Drone', 'myModel': 'veroviz/models/drone.gltf', 'myCesiumColor': 'Cesium.Color.RED', 'myLeafletColor':'red', 'myArcStyle':'solid', 'modelScale': 100,  'modelMinPxSize': 100,
    'alt': 14},
    'Drone and Package': {'myObjectID': 'Drone and Package', 'myModel': 'veroviz/models/Drone_and_Package.gltf', 'myCesiumColor': 'Cesium.Color.RED', 'myLeafletColor':'red', 'myArcStyle':'solid', 'modelScale': 100,  'modelMinPxSize': 100,
    'alt': 14},
    'Drone no Package': {'myObjectID': 'Drone no Package', 'myModel': 'veroviz/models/Drone_no_Package.gltf', 'myCesiumColor': 'Cesium.Color.RED', 'myLeafletColor':'red', 'myArcStyle':'solid', 'modelScale': 100,  'modelMinPxSize': 100,
    'alt': 14},
    'Drone Package': {'myObjectID': 'Drone Package', 'myModel': 'veroviz/models/drone_package.gltf', 'myCesiumColor': 'Cesium.Color.RED', 'myLeafletColor':'red', 'myArcStyle':'solid', 'modelScale': 100,  'modelMinPxSize': 100,
    'alt': 14},
    
    
    
    'iris_black_blue_plus_box_yellow': {'myObjectID': 'iris_black_blue_plus_box_yellow', 'myModel': 'veroviz/models/iris_black_blue_plus_box_yellow.gltf', 'myCesiumColor': 'Cesium.Color.RED', 'myLeafletColor':'red', 'myArcStyle':'solid', 'modelScale': 100,  'modelMinPxSize': 100,
    'alt': 14},
    'iris_with_props_black_blue': {'myObjectID': 'iris_with_props_black_blue', 'myModel': 'veroviz/models/iris_with_props_black_blue.gltf', 'myCesiumColor': 'Cesium.Color.RED', 'myLeafletColor':'red', 'myArcStyle':'solid', 'modelScale': 100,  'modelMinPxSize': 100,
    'alt': 14},
    'iris_with_props_black_green': {'myObjectID': 'iris_with_props_black_green', 'myModel': 'veroviz/models/iris_with_props_black_green.gltf', 'myCesiumColor': 'Cesium.Color.RED', 'myLeafletColor':'red', 'myArcStyle':'solid', 'modelScale': 100,  'modelMinPxSize': 100,
    'alt': 14},
    'iris_with_props_black_orange': {'myObjectID': 'iris_with_props_black_orange', 'myModel': 'veroviz/models/iris_with_props_black_orange.gltf', 'myCesiumColor': 'Cesium.Color.RED', 'myLeafletColor':'red', 'myArcStyle':'solid', 'modelScale': 100,  'modelMinPxSize': 100,
    'alt': 14},
    'iris_with_props_black_pink': {'myObjectID': 'iris_with_props_black_pink', 'myModel': 'veroviz/models/iris_with_props_black_pink.gltf', 'myCesiumColor': 'Cesium.Color.RED', 'myLeafletColor':'red', 'myArcStyle':'solid', 'modelScale': 100,  'modelMinPxSize': 100,
    'alt': 14},
    'iris_with_props_black_purple': {'myObjectID': 'iris_with_props_black_purple', 'myModel': 'veroviz/models/iris_with_props_black_purple.gltf', 'myCesiumColor': 'Cesium.Color.RED', 'myLeafletColor':'red', 'myArcStyle':'solid', 'modelScale': 100,  'modelMinPxSize': 100,
    'alt': 14},
    'iris_with_props_black_red': {'myObjectID': 'iris_with_props_black_red', 'myModel': 'veroviz/models/iris_with_props_black_red.gltf', 'myCesiumColor': 'Cesium.Color.RED', 'myLeafletColor':'red', 'myArcStyle':'solid', 'modelScale': 100,  'modelMinPxSize': 100,
    'alt': 14},
    'iris_with_props_black_yellow': {'myObjectID': 'iris_with_props_black_yellow', 'myModel': 'veroviz/models/iris_with_props_black_yellow.gltf', 'myCesiumColor': 'Cesium.Color.RED', 'myLeafletColor':'red', 'myArcStyle':'solid', 'modelScale': 100,  'modelMinPxSize': 100,
    'alt': 14},
    'iris_with_props_blue_white': {'myObjectID': 'iris_with_props_blue_white', 'myModel': 'veroviz/models/iris_with_props_blue_white.gltf', 'myCesiumColor': 'Cesium.Color.RED', 'myLeafletColor':'red', 'myArcStyle':'solid', 'modelScale': 100,  'modelMinPxSize': 100,
    'alt': 14},
    'iris_with_props_gray_blue': {'myObjectID': 'iris_with_props_gray_blue', 'myModel': 'veroviz/models/iris_with_props_gray_blue.gltf', 'myCesiumColor': 'Cesium.Color.RED', 'myLeafletColor':'red', 'myArcStyle':'solid', 'modelScale': 100,  'modelMinPxSize': 100,
    'alt': 14},
    'iris_with_props_gray_green': {'myObjectID': 'iris_with_props_gray_green', 'myModel': 'veroviz/models/iris_with_props_gray_green.gltf', 'myCesiumColor': 'Cesium.Color.RED', 'myLeafletColor':'red', 'myArcStyle':'solid', 'modelScale': 100,  'modelMinPxSize': 100,
    'alt': 14},
    'iris_with_props_gray_orange': {'myObjectID': 'iris_with_props_gray_orange', 'myModel': 'veroviz/models/iris_with_props_gray_orange.gltf', 'myCesiumColor': 'Cesium.Color.RED', 'myLeafletColor':'red', 'myArcStyle':'solid', 'modelScale': 100,  'modelMinPxSize': 100,
    'alt': 14},
    'iris_with_props_gray_pink': {'myObjectID': 'iris_with_props_gray_pink', 'myModel': 'veroviz/models/iris_with_props_gray_pink.gltf', 'myCesiumColor': 'Cesium.Color.RED', 'myLeafletColor':'red', 'myArcStyle':'solid', 'modelScale': 100,  'modelMinPxSize': 100,
    'alt': 14},
    'iris_with_props_gray_purple': {'myObjectID': 'iris_with_props_gray_purple', 'myModel': 'veroviz/models/iris_with_props_gray_purple.gltf', 'myCesiumColor': 'Cesium.Color.RED', 'myLeafletColor':'red', 'myArcStyle':'solid', 'modelScale': 100,  'modelMinPxSize': 100,
    'alt': 14},
    'iris_with_props_gray_red': {'myObjectID': 'iris_with_props_gray_red', 'myModel': 'veroviz/models/iris_with_props_gray_red.gltf', 'myCesiumColor': 'Cesium.Color.RED', 'myLeafletColor':'red', 'myArcStyle':'solid', 'modelScale': 100,  'modelMinPxSize': 100,
    'alt': 14},
    'iris_with_props_gray_yellow': {'myObjectID': 'iris_with_props_gray_yellow', 'myModel': 'veroviz/models/iris_with_props_gray_yellow.gltf', 'myCesiumColor': 'Cesium.Color.RED', 'myLeafletColor':'red', 'myArcStyle':'solid', 'modelScale': 100,  'modelMinPxSize': 100,
    'alt': 14},
    'iris_with_props_green_white': {'myObjectID': 'iris_with_props_green_white', 'myModel': 'veroviz/models/iris_with_props_green_white.gltf', 'myCesiumColor': 'Cesium.Color.RED', 'myLeafletColor':'red', 'myArcStyle':'solid', 'modelScale': 100,  'modelMinPxSize': 100,
    'alt': 14},
    'iris_with_props_lightblue_white': {'myObjectID': 'iris_with_props_lightblue_white', 'myModel': 'veroviz/models/iris_with_props_lightblue_white.gltf', 'myCesiumColor': 'Cesium.Color.RED', 'myLeafletColor':'red', 'myArcStyle':'solid', 'modelScale': 100,  'modelMinPxSize': 100,
    'alt': 14},
    'iris_with_props_orange_white': {'myObjectID': 'iris_with_props_orange_white', 'myModel': 'veroviz/models/iris_with_props_orange_white.gltf', 'myCesiumColor': 'Cesium.Color.RED', 'myLeafletColor':'red', 'myArcStyle':'solid', 'modelScale': 100,  'modelMinPxSize': 100,
    'alt': 14},
    'iris_with_props_pink_white': {'myObjectID': 'iris_with_props_pink_white', 'myModel': 'veroviz/models/iris_with_props_pink_white.gltf', 'myCesiumColor': 'Cesium.Color.RED', 'myLeafletColor':'red', 'myArcStyle':'solid', 'modelScale': 100,  'modelMinPxSize': 100,
    'alt': 14},
    'iris_with_props_purple_white': {'myObjectID': 'iris_with_props_purple_white', 'myModel': 'veroviz/models/iris_with_props_purple_white.gltf', 'myCesiumColor': 'Cesium.Color.RED', 'myLeafletColor':'red', 'myArcStyle':'solid', 'modelScale': 100,  'modelMinPxSize': 100,
    'alt': 14},
    'iris_with_props_red_white': {'myObjectID': 'iris_with_props_red_white', 'myModel': 'veroviz/models/iris_with_props_red_white.gltf', 'myCesiumColor': 'Cesium.Color.RED', 'myLeafletColor':'red', 'myArcStyle':'solid', 'modelScale': 100,  'modelMinPxSize': 100,
    'alt': 14},
    'iris_with_props_yellow_white': {'myObjectID': 'iris_with_props_yellow_white', 'myModel': 'veroviz/models/iris_with_props_yellow_white.gltf', 'myCesiumColor': 'Cesium.Color.RED', 'myLeafletColor':'red', 'myArcStyle':'solid', 'modelScale': 100,  'modelMinPxSize': 100,
    'alt': 14},
    'Blue Predator': {'myObjectID': 'Blue Predator', 'myModel': 'veroviz/models/predator_blue.gltf', 'myCesiumColor': 'Cesium.Color.RED', 'myLeafletColor':'red', 'myArcStyle':'solid', 'modelScale': 100,  'modelMinPxSize': 100,
    'alt': 14},
    'Gray Predator': {'myObjectID': 'Gray Predator', 'myModel': 'veroviz/models/predator_gray.gltf', 'myCesiumColor': 'Cesium.Color.RED', 'myLeafletColor':'red', 'myArcStyle':'solid', 'modelScale': 100,  'modelMinPxSize': 100,
    'alt': 14},
    'UB Plane': {'myObjectID': 'UB Plane', 'myModel': 'veroviz/models/ub_airplane.gltf', 'myCesiumColor': 'Cesium.Color.RED', 'myLeafletColor':'red', 'myArcStyle':'solid', 'modelScale': 100,  'modelMinPxSize': 100,
    'alt': 14},
    'UPS Plane': {'myObjectID': 'UPS Plane', 'myModel': 'veroviz/models/ups_airplane.gltf', 'myCesiumColor': 'Cesium.Color.RED', 'myLeafletColor':'red', 'myArcStyle':'solid', 'modelScale': 100,  'modelMinPxSize': 100,
    'alt': 14},
    'ZZZDrone and Package': {'myObjectID': 'ZZZDrone and Package', 'myModel': 'veroviz/models/zzzDrone_and_Package.gltf', 'myCesiumColor': 'Cesium.Color.RED', 'myLeafletColor':'red', 'myArcStyle':'solid', 'modelScale': 100,  'modelMinPxSize': 100,
    'alt': 14},
    
}

array = []
for i in vInfo:
    array.append(vInfo[i])
    
infoDF = pd.DataFrame(array)
infoDF
# Out:
#                myObjectID                                         myModel  \
# 0              Army Truck                   veroviz/models/ArmyTruck.gltf
# 1                Blue Car                    veroviz/models/car_blue.gltf
# 2       Blue Car Small v3           veroviz/models/car_blue-small_v3.gltf
# 3   Blue Car Small v3 -90  veroviz/models/car_blue-small_v3_rotate90.gltf
# 4             Car carrier                 veroviz/models/car_carrier.gltf
# ..                    ...                                             ...
# 72          Blue Predator               veroviz/models/predator_blue.gltf
# 73          Gray Predator               veroviz/models/predator_gray.gltf
# 74               UB Plane                 veroviz/models/ub_airplane.gltf
# 75              UPS Plane                veroviz/models/ups_airplane.gltf
# 76   ZZZDrone and Package        veroviz/models/zzzDrone_and_Package.gltf
#
#        myCesiumColor myLeafletColor myArcStyle  modelScale  modelMinPxSize  \
# ...

# %%
assignmentsDF = vrv.initDataframe('assignments')

center = [42.99913934731591, -78.77751946449281]     # UB Field 
radius = 20  # meters

groundAngleDelta = 359/len(modelsDF[modelsDF['alt'] == 0])
airAngleDelta    = 359/len(modelsDF[modelsDF['alt'] > 0])

groundAngle = 0
airAngle = 0
for i in range(len(modelsDF)):
    if modelsDF.loc[i]['alt'] > 0:
        airAngle += airAngleDelta
        angle     = airAngle
    else: 
        groundAngle += groundAngleDelta
        angle        = groundAngle

    loc = vrv.pointInDistance2D(loc=[center[0], center[1], modelsDF.loc[i]['alt']], 
                                direction=angle, distMeters=radius)

    assignmentsDF = vrv.addStaticAssignment(initAssignments = assignmentsDF,
                                            objectID        = modelsDF.loc[i]['objectID'],
                                            modelFile       = 'veroviz/models/%s' % (modelsDF.loc[i]['model']),
                                            loc             = loc,
                                            startTimeSec    = 0.0,
                                            endTimeSec      = 30)
assignmentsDF

# %%
# Create Cesium Example
vrv.createCesium(assignments = assignmentsDF, 
                 nodes       = None, 
                 startDate   = None, 
                 startTime   = '08:00:00', 
                 postBuffer  = 30, 
                 cesiumDir   = os.environ['CESIUMDIR'],        
                 problemDir  = 'veroviz_demo/all_models',      # <-- a sub-directory of cesiumDir
                 )
